# %%
import requests
import json
import pandas as pd

# URL de la API que contiene la tabla
url = "http://api.datosabiertos.enacom.gob.ar/api/v2/dashboards/ACCES-A-INTER.json/?auth_key=gnZZUMuXHbgCx6L2llGxQ26Aqfgqhw3qr3Te1qwQ"

# Realizar solicitud GET a la API
response = requests.get(url)

# Verificar si la solicitud fue exitosa
if response.status_code == 200:
    # Convertir la respuesta a formato JSON
    data = json.loads(response.text)
    
    # Crear un DataFrame de pandas desde los datos JSON
    df = pd.DataFrame(data)
    
    # Imprimir el DataFrame
    print(df)
else:
    print("Error al obtener los datos de la API")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\1 EMPRESA 2\2-MARKeTING\DATA SCIENCE\1-clases\1_Labs\PI_DataAnalyst\Proyecto_analytics\test.ipynb Cell 1 in <cell line: 12>()
#      <a href='vscode-notebook-cell:/d%3A/1%20EMPRESA%202/2-MARKeTING/DATA%20SCIENCE/1-clases/1_Labs/PI_DataAnalyst/Proyecto_analytics/test.ipynb#X12sZmlsZQ%3D%3D?line=13'>14</a> data = json.loads(response.text)
#      <a href='vscode-notebook-cell:/d%3A/1%20EMPRESA%202/2-MARKeTING/DATA%20SCIENCE/1-clases/1_Labs/PI_DataAnalyst/Proyecto_analytics/test.ipynb#X12sZmlsZQ%3D%3D?line=15'>16</a> # Crear un DataFrame de pandas desde los datos JSON
# ---> <a href='vscode-notebook-cell:/d%3A/1%20EMPRESA%202/2-MARKeTING/DATA%20SCIENCE/1-clases/1_Labs/PI_DataAnalyst/Proyecto_analytics/test.ipynb#X12sZmlsZQ%3D%3D?line=16'>17</a> df = pd.DataFrame(data)
# ...

# %%
historico_velocidad_internet=pd.read_csv ('datasets/velocidad/historico_velocidad_internet.csv')
historico_velocidad_internet.head(10)
# Out:
#     Año  Trimestre Mbps (Media de bajada)    Trimestre.1
# 0  2022          3                  62,46  Jul-Sept 2022
# 1  2022          2                  58,44   Abr-Jun 2022
# 2  2022          1                  55,11   Ene-Mar 2022
# 3  2021          4                  52,34   Oct-Dic 2021
# 4  2021          3                  48,46  Jul-Sept 2021
# 5  2021          2                  45,63   Abr-Jun 2021
# 6  2021          1                  43,11   Ene-Mar 2021
# 7  2020          4                  42,36   Oct-Dic 2020
# 8  2020          3                  40,67  Jul-Sept 2020
# 9  2020          2                  38,32   Abr-Jun 2020
